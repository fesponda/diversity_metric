# %% [markdown]
# ### This file contains the code to compute the similarity metric between an original file and its variants. It is parametrized by whether the file should be read as instructions or bytes.
#
# Some earier file has the code to compute similarity between variants and plot this against effectiveness to prevent attacks

# %%
from scipy.stats import spearmanr, stats
from scipy.spatial.distance import euclidean
from random import randint, shuffle,sample,random
from os import listdir
from os.path import isfile, join
import numpy as np
import matplotlib.pyplot as plt
% matplotlib inline
path='/Users/fesponda/research/Diversity/Data/probNog_probBilr_randomized_2/'

ORIGINAL_FILE=path+'original'
TRANSFORMATION_INTENSITY_FILE='percent_items_moved'
OUTPUT_GRAPH='probNog_probBilr_randomized_2.pdf'

###Variable that controls if data is treated as bytes or instructions
BYTE_FILE=True
if BYTE_FILE:
    TRANSFORMS_DIR=path+'binaries/'
else:
    TRANSFORMS_DIR=path+'instructions/'

# %% [markdown]
# # Function Definitions

# %%
def read_instructions(file1):
    f=open(file1, 'r')
    P1=[]
    for line in f:
        P1.append(line.strip().replace(" ",""))
    return P1

# %%
def read_ELF(file1):
    with open(file1, 'rb') as f:
        P1=list(f.read())
    return P1

# %%
#P1=read_instructions(ORIGINAL_FILE)

# %%
def read_instructions_only_inst(file1):
    f=open(file1, 'r')
    P1=[]
    for line in f:
        P1.append(line.split()[0])
    return P1

# %%
def read_file(file1,BYTE_FILE):
    if BYTE_FILE: 
        return read_ELF(file1)
    else:
        return read_instructions(file1)

# %%
##Create dictionary. For each byte in the block we create unique entry. If a byte is repeated we append if its the first, second, etc occurrence
def P1_dictionary(P1):
    P1_dict={}
    P1_occ={}
    for index,byte in enumerate(P1):   
        if byte  in P1_occ.keys():
            P1_occ[byte]+=1
        else:
            P1_occ[byte]=1
        value=str(byte)+'_'+str(P1_occ[byte]) ## here we create a unique value for each byte in the section
        P1_dict[value]=index+1 #we start to count at 1
    return P1_dict

# %%
####Rank instructions of a block according to first file template
def rank_P2(P1_dict,P2,intersection=False):
    a=[]        
    b=[]
    med_rank=len(P1_dict.keys())/2.0
    P2_dict={}
    P2_occ={}
    for index,byte in enumerate(P2):   
        if byte  in P2_occ.keys():
            P2_occ[byte]+=1
        else:
            P2_occ[byte]=1
        value=str(byte)+'_'+str(P2_occ[byte]) ## here we create a unique value for each byte in the section
        if value in P1_dict.keys():
            P2_dict[value]=P1_dict[value]
            a.append(index+1)
            b.append(P2_dict[value])
        elif not intersection:
            P2_dict[value]=0 ###zero for no existent value....check Maybe not bother, Maybe random, maybe average
            P2_dict[value]=med_rank 
            #P2_dict[value]=randint(1,90)
            a.append(index+1)
            b.append(P2_dict[value])
            
    #print(len(a),len(b))
    return a,b

# %% [markdown]
# # Execution

# %%
# Get list of files
l = [f for f in listdir(TRANSFORMS_DIR) if isfile(join(TRANSFORMS_DIR, f)) and f[0]!='.']

# %%
# Compute similarity between original and each transform
P1=read_file(ORIGINAL_FILE,BYTE_FILE)
P1_dict=P1_dictionary(P1)
result=[]
for knob in l:
    P2=read_file(TRANSFORMS_DIR+knob,BYTE_FILE)
    a,b=rank_P2(P1_dict,P2,intersection=True)
    corr,p=spearmanr(a,b)
    result.append((knob,corr,p))
print(result)
# Out:
# [('1vs#3probNog_probBilr-move_globals_1700_2.txt', 0.9380419704238016, 0.0), ('1vs#3probNog_probBilr-move_globals_900_2.txt', 0.9396458066811044, 0.0), ('1vs#3probNog_probBilr-move_globals_900_0.txt', 0.9510563308221227, 0.0), ('1vs#3probNog_probBilr-move_globals_1700_0.txt', 0.9365430856435003, 0.0), ('1vs#3probNog_probBilr-move_globals_1700_1.txt', 0.9418736156239372, 0.0), ('1vs#3probNog_probBilr-move_globals_900_1.txt', 0.9582019109545286, 0.0), ('1vs#3probNog_probBilr-move_globals_1600_0.txt', 0.9421660836469786, 0.0), ('1vs#3probNog_probBilr-move_globals_2000_2.txt', 0.9423476595922149, 0.0), ('1vs#3probNog_probBilr-move_globals_800_0.txt', 0.9398967277114567, 0.0), ('1vs#3probNog_probBilr-move_globals_800_1.txt', 0.9532233056948167, 0.0), ('1vs#3probNog_probBilr-move_globals_1600_1.txt', 0.9402733975919813, 0.0), ('1vs#3probNog_probBilr-move_globals_2000_1.txt', 0.9411504528604452, 0.0), ('1vs#3probNog_probBilr-move_globals_800_2.txt', 0.9343092399882065, 0.0), ('1vs#3probNog_probBilr-move_globals_2000_0.txt', 0.9396588236226072, 0.0), ('1vs#3probNog_probBilr-move_globals_1600_2.txt', 0.939873857513126, 0.0), ('1vs#3probNog_probBilr-move_globals_1400_0.txt', 0.9429392936041119, 0.0), ('1vs#3probNog_probBilr-move_globals_1400_1.txt', 0.9562309097726568, 0.0), ('1vs#3probNog_probBilr-move_globals_1400_2.txt', 0.9592693472134681, 0.0), ('1vs#3probNog_probBilr-move_globals_1500_2.txt', 0.9386998658572286, 0.0), ('1vs#3probNog_probBilr-move_globals_1500_0.txt', 0.9338627725621284, 0.0), ('1vs#3probNog_probBilr-move_globals_1500_1.txt', 0.9381182642241178, 0.0), ('1vs#3probNog_probBilr-move_globals_1900_2.txt', 0.9410544624581413, 0.0), ('1vs#3probNog_probBilr-move_globals_700_2.txt', 0.9381311121032909, 0.0), ('1vs#3probNog_probBilr-move_globals_1000_1.txt', 0.936047375109777, 0.0), ('1vs#3probNog_probBilr-move_globals_1000_0.txt', 0.9364623306957935, 0.0), ('1vs#3probNog_probBilr-move_globals_1900_1.txt', 0.9394525246499005, 0.0), ('1vs#3probNog_probBilr-move_globals_700_1.txt', 0.9547170815279471, 0.0), ('1vs#3probNog_probBilr-move_globals_1000_2.txt', 0.9360021548675658, 0.0), ('1vs#3probNog_probBilr-move_globals_700_0.txt', 0.9530000160335309, 0.0), ('1vs#3probNog_probBilr-move_globals_1900_0.txt', 0.9383268388019407, 0.0), ('1vs#3probNog_probBilr-move_globals_600_1.txt', 0.9579078578594097, 0.0), ('1vs#3probNog_probBilr-move_globals_1800_1.txt', 0.9366336607370254, 0.0), ('1vs#3probNog_probBilr-move_globals_1100_2.txt', 0.9383683975828127, 0.0), ('1vs#3probNog_probBilr-move_globals_1800_0.txt', 0.9383306451609559, 0.0), ('1vs#3probNog_probBilr-move_globals_600_0.txt', 0.9557902298746599, 0.0), ('1vs#3probNog_probBilr-move_globals_600_2.txt', 0.9345659101910948, 0.0), ('1vs#3probNog_probBilr-move_globals_1800_2.txt', 0.9372304822540475, 0.0), ('1vs#3probNog_probBilr-move_globals_1100_1.txt', 0.9359513759731553, 0.0), ('1vs#3probNog_probBilr-move_globals_1100_0.txt', 0.9348350181975789, 0.0), ('1vs#3probNog_probBilr-move_globals_1300_2.txt', 0.939908704559699, 0.0), ('1vs#3probNog_probBilr-move_globals_1300_1.txt', 0.9400468855626622, 0.0), ('1vs#3probNog_probBilr-move_globals_1300_0.txt', 0.9380465265731316, 0.0), ('1vs#3probNog_probBilr-move_globals_1200_1.txt', 0.9388799309266235, 0.0), ('1vs#3probNog_probBilr-move_globals_500_2.txt', 0.940560357521246, 0.0), ('1vs#3probNog_probBilr-move_globals_1200_0.txt', 0.9377289948046137, 0.0), ('1vs#3probNog_probBilr-move_globals_1200_2.txt', 0.935935074842545, 0.0), ('1vs#3probNog_probBilr-move_globals_500_1.txt', 0.9588430932450708, 0.0), ('1vs#3probNog_probBilr-move_globals_500_0.txt', 0.9999999999999999, 0.0)]

# %%
# Pair up the similarity with the intensity of the transform. This is very specific to the current file 
# formats. The intensity file has a fragment of the transforms file name and the intensity comma separated

result=sorted(result,key=lambda x: x[0])
with open(path+TRANSFORMATION_INTENSITY_FILE) as fp:
    lines=fp.readlines()

perc_moved=[]
for line in lines:
    l=line.rstrip().split(',')
    perc_moved.append((l[0],float(l[1])))
perc_moved=sorted(perc_moved,key=lambda x: x[0])
###check could of sorted but I rather check

simi=[]
move=[]

for sim in result:
    for perc in perc_moved:
        if perc[0] in sim[0]:
            print (perc[0], sim[0])
            simi.append(sim[1])
            move.append(perc[1])
            break
final=zip(result,perc_moved)
# Out:
# 1000_0 1vs#3probNog_probBilr-move_globals_1000_0.txt
# 1000_1 1vs#3probNog_probBilr-move_globals_1000_1.txt
# 1000_2 1vs#3probNog_probBilr-move_globals_1000_2.txt
# 1100_0 1vs#3probNog_probBilr-move_globals_1100_0.txt
# 1100_1 1vs#3probNog_probBilr-move_globals_1100_1.txt
# 1100_2 1vs#3probNog_probBilr-move_globals_1100_2.txt
# 1200_0 1vs#3probNog_probBilr-move_globals_1200_0.txt
# 1200_1 1vs#3probNog_probBilr-move_globals_1200_1.txt
# 1200_2 1vs#3probNog_probBilr-move_globals_1200_2.txt
# 1300_0 1vs#3probNog_probBilr-move_globals_1300_0.txt
# 1300_1 1vs#3probNog_probBilr-move_globals_1300_1.txt
# 1300_2 1vs#3probNog_probBilr-move_globals_1300_2.txt
# 1400_0 1vs#3probNog_probBilr-move_globals_1400_0.txt
# 1400_1 1vs#3probNog_probBilr-move_globals_1400_1.txt
# 1400_2 1vs#3probNog_probBilr-move_globals_1400_2.txt
# 1500_0 1vs#3probNog_probBilr-move_globals_1500_0.txt
# 1500_1 1vs#3probNog_probBilr-move_globals_1500_1.txt
# 1500_2 1vs#3probNog_probBilr-move_globals_1500_2.txt
# 1600_0 1vs#3probNog_probBilr-move_globals_1600_0.txt
# 1600_1 1vs#3probNog_probBilr-move_globals_1600_1.txt
# 1600_2 1vs#3probNog_probBilr-move_globals_1600_2.txt
# 1700_0 1vs#3probNog_probBilr-move_globals_1700_0.txt
# 1700_1 1vs#3probNog_probBilr-move_globals_1700_1.txt
# 1700_2 1vs#3probNog_probBilr-move_globals_1700_2.txt
# 1800_0 1vs#3probNog_probBilr-move_globals_1800_0.txt
# 1800_1 1vs#3probNog_probBilr-move_globals_1800_1.txt
# 1800_2 1vs#3probNog_probBilr-move_globals_1800_2.txt
# 1900_0 1vs#3probNog_probBilr-move_globals_1900_0.txt
# 1900_1 1vs#3probNog_probBilr-move_globals_1900_1.txt
# 1900_2 1vs#3probNog_probBilr-move_globals_1900_2.txt
# 2000_0 1vs#3probNog_probBilr-move_globals_2000_0.txt
# 2000_1 1vs#3probNog_probBilr-move_globals_2000_1.txt
# 2000_2 1vs#3probNog_probBilr-move_globals_2000_2.txt
# 500_0 1vs#3probNog_probBilr-move_globals_500_0.txt
# 500_1 1vs#3probNog_probBilr-move_globals_500_1.txt
# 500_2 1vs#3probNog_probBilr-move_globals_500_2.txt
# 600_0 1vs#3probNog_probBilr-move_globals_600_0.txt
# 600_1 1vs#3probNog_probBilr-move_globals_600_1.txt
# 600_2 1vs#3probNog_probBilr-move_globals_600_2.txt
# 700_0 1vs#3probNog_probBilr-move_globals_700_0.txt
# 700_1 1vs#3probNog_probBilr-move_globals_700_1.txt
# 700_2 1vs#3probNog_probBilr-move_globals_700_2.txt
# 800_0 1vs#3probNog_probBilr-move_globals_800_0.txt
# 800_1 1vs#3probNog_probBilr-move_globals_800_1.txt
# 800_2 1vs#3probNog_probBilr-move_globals_800_2.txt
# 900_0 1vs#3probNog_probBilr-move_globals_900_0.txt
# 900_1 1vs#3probNog_probBilr-move_globals_900_1.txt
# 900_2 1vs#3probNog_probBilr-move_globals_900_2.txt

# %%
print(len(move),len(simi))
# Out:
# 48 48

# %%
plt.scatter(move,simi,marker='.')
plt.ylabel('Similarity')
plt.xlabel('Percentage Moved')

plt.savefig(OUTPUT_GRAPH)

# %%
s=zip(move,simi)
list(s)
# Out:
# [(30.1, 0.9364623306957935),
#  (30.1, 0.936047375109777),
#  (30.5, 0.9360021548675658),
#  (34.3, 0.9348350181975789),
#  (34.3, 0.9359513759731553),
#  (34.4, 0.9383683975828127),
#  (37.4, 0.9377289948046137),
#  (37.5, 0.9388799309266235),
#  (37.5, 0.935935074842545),
#  (40.0, 0.9380465265731316),
#  (40.1, 0.9400468855626622),
#  (40.1, 0.939908704559699),
#  (43.8, 0.9429392936041119),
#  (43.8, 0.9562309097726568),
#  (43.8, 0.9592693472134681),
#  (47.0, 0.9338627725621284),
#  (46.6, 0.9381182642241178),
#  (46.8, 0.9386998658572286),
#  (50.5, 0.9421660836469786),
#  (50.5, 0.9402733975919813),
#  (50.5, 0.939873857513126),
#  (52.7, 0.9365430856435003),
#  (53.1, 0.9418736156239372),
#  (53.1, 0.9380419704238016),
#  (56.1, 0.9383306451609559),
#  (56.1, 0.9366336607370254),
#  (56.1, 0.9372304822540475),
#  (59.1, 0.9383268388019407),
#  (59.4, 0.9394525246499005),
#  (59.4, 0.9410544624581413),
#  (62.4, 0.9396588236226072),
#  (62.4, 0.9411504528604452),
#  (62.5, 0.9423476595922149),
#  (16.0, 0.9999999999999999),
#  (16.0, 0.9588430932450708),
#  (15.3, 0.940560357521246),
#  (18.7, 0.9557902298746599),
#  (18.6, 0.9579078578594097),
#  (18.8, 0.9345659101910948),
#  (21.8, 0.9530000160335309),
#  (21.8, 0.9547170815279471),
#  (22.1, 0.9381311121032909),
#  (25.4, 0.9398967277114567),
#  (24.7, 0.9532233056948167),
#  (25.3, 0.9343092399882065),
#  (28.4, 0.9510563308221227),
#  (28.0, 0.9582019109545286),
#  (28.1, 0.9396458066811044)]

# %%
print(len(set(P1).intersection(set(P2))),len(set(P1)),len(set(P2)))
# Out:
# 33723 33723 33723

# %%
print(len(P2),len(set(P2)),len(set(P2))/len(P2))
# Out:
# 184223 33723 0.18305531882555381

# %%
set(P1).intersection(set(P2))
# Out:
# {'movdword[rbp-b8],ecx',
#  'learsi,[7+117cbc]',
#  'movssxmm0,[rdi+48]',
#  'jned689c',
#  'jed3414',
#  'jmpa7921',
#  'learcx,[rbp-220]',
#  'je77ec3',
#  'jmpcb96f',
#  'movqword[7+3a8a69],rax',
#  'movss[rbp-48],xmm0',
#  'learax,[7+115591]',
#  'jmpqword[6+33653a]',
#  'jeaa443',
#  'learsi,[7+10b80f]',
#  'movdword[rax],edx',
#  'jsc6c7d',
#  'jmpa0f8a',
#  'jne5104c',
#  'leardx,[7+118b09]',
#  'leardi,[7+10612a]',
#  'je6bc5a',
#  'learax,[7+fa9b1]',
#  'jnee73f1',
#  'learsi,[7+10f770]',
#  'movedx,dword[rax+3c]',
#  'lear8,[7+10ffe9]',
#  'je4f01a',
#  'leardi,[7+105f70]',
#  'jnscf47b',
#  'push101',
#  'jmpc69a5',
#  'jneb2207',
#  'movrcx,qword[rax+40]',
#  'je96b26',
#  'jmp992b1',
#  'movsxedi,byte[rbp-13]',
#  'jmp58662',
#  'jl9e44b',
#  'movdword[rax],r15d',
#  'jedd1b7',
#  'learax,[7+ff7c5]',
#  'call5c6a7',
#  'jmp8380b',
#  'jnee5be9',
#  'movesi,68a',
#  'jmpb40c0',
#  'learcx,[rbp-240]',
#  'learax,[7+103cb9]',
#  'je7b94f',
#  'jmpf4956',
#  'jmpeb0f8',
#  'je4ebe0',
#  'jne6c6fa',
#  'leardi,[7+10b831]',
#  'jmpce190',
#  'learsi,[7+115790]',
#  'jmpcbb27',
#  'movrbx,qword[7+348639]',
#  'movbyte[rbp-31],1',
#  'jmp75253',
#  'je7fc78',
#  'addqword[rbp-10],1',
#  'movr9,qword[rbp-20]',
#  'push285',
#  'oreax,20',
#  'jmp6bbdf',
#  'moveax,dword[6+340442]',
#  'call47480',
#  'leardi,[7+fd7b1]',
#  'jns6bb91',
#  'jne5facd',
#  'movebp,edx',
#  'movrdx,qword[rbp-2100]',
#  'movssxmm0,[r14]',
#  'movrdx,qword[rcx+18]',
#  'movesi,35c',
#  'jmpb158b',
#  'jmpce853',
#  'jnea48db',
#  'je98a19',
#  'callbc7c0',
#  'moveax,dword[6+33aa3e]',
#  'jnecd44e',
#  'jee17ff',
#  'call70a04',
#  'jnpf6c5f',
#  'movesi,30f',
#  'jmp93993',
#  'movrcx,qword[r12]',
#  'movr8,qword[rbp-70]',
#  'jeaa287',
#  'cmpr9,qword[rsp-8]',
#  'jmp948ee',
#  'jeb1fa9',
#  'jmp666e8',
#  'leardx,[7+f7831]',
#  'learcx,[7+33f239]',
#  'learsi,[7+1153f3]',
#  'jnef32fe',
#  'learbp,[7+33d879]',
#  'jnecb29d',
#  'je5abaa',
#  'learsi,[7+10630c]',
#  'jne7d6de',
#  'jmpe1822',
#  'jmp6bdd3',
#  'movqword[rbp-128],rdi',
#  'jed1497',
#  'leardx,[7+4d14d]',
#  'push24',
#  'jne9d42a',
#  'notr10d',
#  'learsi,[7+10af89]',
#  'call8101a',
#  'je4b250',
#  'learsi,[7+106263]',
#  'call6b40a',
#  'jmp4c2fb',
#  'movr10d,dword[rbp-3c]',
#  'movzxedi,byte[rdi+4]',
#  'learax,[7+c2159]',
#  'leardi,[7+1050a9]',
#  'jmp68af6',
#  'jneeaf9c',
#  'callqword[rbx+50]',
#  'jmp5887e',
#  'movbyte[7-c73ca],0',
#  'cmpdword[rbp-14],fff',
#  'call45c00',
#  'learsi,[7+112219]',
#  'je51a9f',
#  'moveax,115',
#  'push161',
#  'jnsf2aea',
#  'je677f8',
#  'jed534e',
#  'learax,[7+fe62d]',
#  'pushe9',
#  'learsi,[7+f7d25]',
#  'leaecx,[rax*4]',
#  'movr10d,dword[rbp-50]',
#  'movsxeax,byte[rbp-14]',
#  'moveax,dword[rax+2c]',
#  'je9955f',
#  'movsxdrax,ecx',
#  'sareax,1',
#  'je6634b',
#  'movss[rsp+4],xmm4',
#  'lear9,[7+1115b7]',
#  'learcx,[7+3ad7b9]',
#  'call9ab9b',
#  'movesi,5c',
#  'jmpa5740',
#  'movrcx,qword[rbp-8]',
#  'jne63c16',
#  'leaedx,[r12+1]',
#  'call4bb63',
#  'movsxdrsi,ecx',
#  'je514fd',
#  'jned2736',
#  'lear15,[7+3337b4]',
#  'movrax,qword[7+33f149]',
#  'jleb2820',
#  'leardi,[7+10a384]',
#  'jne8fe93',
#  'movdword[6+3a8bc6],eax',
#  'learsi,[7+1084fb]',
#  'movr10,qword[rbp-68]',
#  'jebee1f',
#  'movedx,1e',
#  'moveax,dword[rax+rdx*4]',
#  'cmpal,43',
#  'movzxecx,al',
#  'push283',
#  'jmp83e7c',
#  'jmpa268b',
#  'jmp9c674',
#  'jmp666c0',
#  'learcx,[rbp-38]',
#  'jneba430',
#  'jsd4e16',
#  'cmpeax,64',
#  'learsi,[7+103ce3]',
#  'jmp66f9c',
#  'movr8d,dword[r8+b8]',
#  'subsdxmm3,[rsp+8]',
#  'learsi,[7+f7ecc]',
#  'learsi,[7+103549]',
#  'movdword[rax],2',
#  'adddword[rbp-60],1',
#  'jmp9e6cb',
#  'jgac563',
#  'jneba727',
#  'jeb1a24',
#  'shrr8,3f',
#  'leardi,[7+f7064]',
#  'learsi,[7+1161e4]',
#  'je55ec6',
#  'jmp4d257',
#  'movzxedx,byte[rbp-81e]',
#  'jmp8b8e1',
#  'learcx,[rbp-2030]',
#  'addqword[rsp+18],8',
#  'jne4b05c',
#  'jea67d5',
#  'movdword[rax+a4],1ffe',
#  'jnea33b9',
#  'cmpesi,2',
#  'jmpqword[6+33690a]',
#  'jmpa207a',
#  'movrdx,qword[rdx+8]',
#  'push333',
#  'leardi,[7+ee436]',
#  'leardi,[7+fe191]',
#  'leardx,[7+2f6c8a]',
#  'jmpcce38',
#  'leardx,[7+332699]',
#  'movbyte[rbx],al',
#  'movssxmm2,[rbx+60]',
#  'jmp6099a',
#  'jne540b4',
#  'je66532',
#  'call554bb',
#  'jneb00bc',
#  'leardx,[rbp-830]',
#  'movedi,3e8',
#  'movqword[7+2e80e1],rax',
#  'calldeabf',
#  'jmpb47f0',
#  'jmp69575',
#  'leaebx,[rax+4]',
#  'cmpbyte[rbp-19],27',
#  'push2b0',
#  'jgf3bbe',
#  'jgb0119',
#  'jmpqword[6+337092]',
#  'jned55ad',
#  'movqword[rbp-180],rax',
#  'jmp96a7d',
#  'jne61fe4',
#  'shrrax,cl',
#  'call46ac0',
#  'jne543d5',
#  'addqword[rbp-10],3',
#  'jned7394',
#  'jbe4d3e2',
#  'jmp5bd5c',
#  'jed4e05',
#  'jmp5dee4',
#  'je7e43a',
#  'je97be8',
#  'adddword[r14+20],1',
#  'learax,[r15+f]',
#  'leaedx,[rbp-1]',
#  'jeed47e',
#  'leardi,[7+114bb2]',
#  'jne95077',
#  'movbyte[rbp-13d],al',
#  'jle5290d',
#  'jmp7fa7c',
#  'jec7740',
#  'learsi,[rbp-28]',
#  'learsi,[7+fa112]',
#  'moveax,12d',
#  'movqword[rsp+18],rcx',
#  'movedx,dword[rdx]',
#  'callb9be0',
#  'jef3a73',
#  'movzxesi,byte[rsp+20]',
#  'subr15d,r13d',
#  'jeb4099',
#  'learsi,[7+10882a]',
#  'cmpdword[rbp-4],1ff',
#  'jmpbe940',
#  'cmpdword[rbp-4],4e38',
#  'jnedf29d',
#  'learsi,[7+108683]',
#  'movrdi,qword[rbp-88]',
#  'learsi,[7+100207]',
#  'jne90ff9',
#  'jnee5d4d',
#  'movrax,qword[rax+e8]',
#  'learax,[7+fd399]',
#  'jmpqword[6+337ab2]',
#  'ja563e4',
#  'je6624c',
#  'movsxecx,al',
#  'movdr14d,xmm3',
#  'jeb44c8',
#  'je4c95e',
#  'movesi,46e',
#  'adddword[rbp-3c],eax',
#  'call469c0',
#  'mulssxmm0,[rbp-58]',
#  'jne6c631',
#  'movdword[rax],61',
#  'learax,[7+fe092]',
#  'pushf9',
#  'push2e6',
#  'jneeffed',
#  'movesi,4e',
#  'moveax,dword[rbp-38]',
#  'je77c7d',
#  'je5f8f3',
#  'andeax,20000',
#  'jmp8a574',
#  'cmpedx,80',
#  'push336',
#  'push18f',
#  'movapsxmm0,xmm3',
#  'moveax,122',
#  'learax,[rbp-f00]',
#  'movrax,qword[rbp-118]',
#  'movbyte[rbp+5],dl',
#  'jsf3e68',
#  'jne8c87c',
#  'je77097',
#  'jec4d1b',
#  'movdword[rax],0',
#  'jne858fd',
#  'push218',
#  'jnebd610',
#  'leardi,[7+1142af]',
#  'leardx,[7+7ea3b]',
#  'moveax,dword[rax+68]',
#  'calle27d7',
#  'jnee04dd',
#  'cmpbyte[rbp-31],0',
#  'learsi,[7+118564]',
#  'movdword[rax+6c],edx',
#  'jsd20c8',
#  'learsi,[7+feff9]',
#  'movsxdrcx,ecx',
#  'je83a44',
#  'jmpf197b',
#  'je9eb68',
#  'jmpf19f6',
#  'movesi,dword[rax+rcx*4]',
#  'movrcx,r12',
#  'jed1fb7',
#  'je95571',
#  'learax,[rbp-120]',
#  'subrsi,rax',
#  'leardx,[7+102a89]',
#  'push335',
#  'jmp72c58',
#  'learax,[7+2819d0]',
#  'jne88f3a',
#  'jg7ec10',
#  'je4a8de',
#  'jnec44ce',
#  'movedi,50',
#  'movrax,r10',
#  'jmp6ce52',
#  'jne4cc0b',
#  'jne6ed68',
#  'imuledx,ebp',
#  'call706bb',
#  'jebbc94',
#  'movecx,dword[rcx+r8*4]',
#  'learsi,[7+33ef09]',
#  'je4c291',
#  'jmpedc42',
#  'js5d211',
#  'movrdx,qword[rax+d0]',
#  'andr15d,1',
#  'jmpbd1ac',
#  'jneee319',
#  'movdword[rax+10],2',
#  'push16b',
#  'learsi,[7+10f836]',
#  'learsi,[7+11220e]',
#  'movedx,16',
#  'jne70824',
#  'jeabe3c',
#  'jmpqword[6+33646a]',
#  'movqword[rdx+68],rax',
#  'learcx,[rbp-c]',
#  'jnscbd8c',
#  'jede278',
#  'call48d50',
#  'learsi,[7+10ed69]',
#  'jeccdd0',
#  'jmpf0a2d',
#  'learax,[rbp-e0]',
#  'jneb58d4',
#  'jec432f',
#  'jmpc6312',
#  'jed745c',
#  'cmpqword[rbp-18],rax',
#  'learsi,[7+100211]',
#  'je5a044',
#  'jne49309',
#  'lear8,[7+117655]',
#  'jmpqword[6+336c92]',
#  'jne9f71d',
#  'call80628',
#  'movssxmm0,[rsp+24]',
#  'call48da0',
#  'poprcx',
#  'movsxdr15,ecx',
#  'jeb80df',
#  'jne6c50f',
#  'movrax,qword[7+2e7090]',
#  'movedx,dword[6+2a6b41]',
#  'leardx,[7+10eaa9]',
#  'leardx,[rbp-30]',
#  'movdword[rsp-4],eax',
#  'imulrax,qword[rbp-10]',
#  'js9270e',
#  'movedx,dword[6+2dbc9c]',
#  'callb5d17',
#  'movzxedx,word[rbp-2]',
#  'jmpqword[6+3364ba]',
#  'movdword[rbx+60],3e48d2ab',
#  'learax,[7+fef49]',
#  'jneada70',
#  'jecc727',
#  'push54',
#  'call9cd00',
#  'movqword[rbp-40],rsp',
#  'je6c986',
#  'addr12d,dword[rbx+98]',
#  'call611f0',
#  'movrax,qword[7+2b1304]',
#  'learax,[7+1033de]',
#  'jg7c0f7',
#  'movesi,4b7',
#  'jmp6a776',
#  'jnedd1c0',
#  'leardx,[7+10eae1]',
#  'call46f70',
#  'leardi,[7+ff516]',
#  'jmpcbdda',
#  'learsi,[7+33f089]',
#  'jsafe82',
#  'jmp9e3a3',
#  'je4fd6c',
#  'jed1d5e',
#  'jed78dd',
#  'cmpbyte[rbp-49],9',
#  'jeeab60',
#  'movbyte[rbp-10],0',
#  'shrrdx,3f',
#  'jmpb0a37',
#  'jmpb85f8',
#  'jmpca622',
#  'jmp92b60',
#  'call48df0',
#  'lear11,[rsi+rax+2]',
#  'movrax,qword[rax+rdx*8+8]',
#  'leardx,[7+10aa89]',
#  'jebad78',
#  'jmpf580e',
#  'learax,[rbp-40]',
#  'leaeax,[rbp+rsi]',
#  'movdword[6+345782],eax',
#  'movss[rbp],xmm1',
#  'jed6b4b',
#  'jmpacd65',
#  'movsxedi,al',
#  'je585e7',
#  'jne8794c',
#  'jnec7691',
#  'jgec2a68',
#  'jmpqword[6+3375c2]',
#  'jne9a6e6',
#  'cmpdword[rbp-4c],1117e',
#  'jneb8112',
#  'movrax,qword[7+33fc09]',
#  'je62559',
#  'movrsi,qword[rbp-8]',
#  'leardi,[7+f7047]',
#  'call4930b',
#  'push93',
#  'jmp57a88',
#  'jed2833',
#  'jne62a98',
#  'je86c19',
#  'jeb353b',
#  'jle8e4af',
#  'je8847e',
#  'learsi,[7+11286d]',
#  'push1f2',
#  'jmp8b4ea',
#  'movqword[rbp-10],1000000',
#  'movdword[rax+38],1',
#  'call48ca0',
#  'jg77656',
#  'jmpcbcfb',
#  'leardi,[7+11172b]',
#  'movecx,2',
#  'moveax,dword[6+10a656]',
#  'addrsp,88',
#  'movrax,qword[rbp-b0]',
#  'jne9d4c7',
#  'jbeb82a8',
#  'jmpd62cb',
#  'cmpal,b',
#  'orecx,edi',
#  'jne7291c',
#  'andr15b,byte[rdx-2]',
#  'jmpa8521',
#  'movesi,6d0',
#  'call8825a',
#  'jmp7fdaf',
#  'call46180',
#  'divssxmm1,[rbp-e8]',
#  'jecdf1a',
#  'jec6a9e',
#  'movzxedx,byte[rbp+rdx-30]',
#  'jge2850',
#  'jaa4963',
#  'learsi,[7+fdbe2]',
#  'movqword[rax+98],6678797a',
#  'movrsi,rsp',
#  'learax,[7+3aac89]',
#  'call48360',
#  'cmprcx,r12',
#  'movdword[10+3a7508],0',
#  'je93d55',
#  'je9334c',
#  'leardx,[7+1189b1]',
#  'movdword[rbp-4],4e2e',
#  'addrbp,40',
#  'jne9aa5a',
#  'movqword[rbp-70],rcx',
#  'jned8600',
#  'jne90acf',
#  'movbyte[rdx+4c],al',
#  'movesi,298',
#  'jne6e69e',
#  'call47bf0',
#  'jmpc2b68',
#  'learax,[7+262b35]',
#  'je7226d',
#  'learsi,[7+fd1f1]',
#  'subqword[rbp-48],1',
#  'imuleax,ecx,e10',
#  'leardx,[7+33fc39]',
#  'learax,[7+b8cf9]',
#  'je92a03',
#  'movqword[rbp-40],r9',
#  'learcx,[rbp-224]',
#  'jlee43f5',
#  'movrax,qwordfs:[28]',
#  'movdword[rbp-2c],r9d',
#  'jeb3a56',
#  'jned7388',
#  'call47b40',
#  'jmpqword[6+336872]',
#  'je9aac4',
#  'jec4977',
#  'movbyte[rbp+rax-130],0',
#  'movbyte[rbp-91],al',
#  'learcx,[rbp-120]',
#  'jnede205',
#  'jsd3211',
#  'jnee9a01',
#  'jmpdbe34',
#  'leardi,[7+d0ac9]',
#  'jmp515b3',
#  'movrax,qword[7+33fc01]',
#  'learax,[7+fa289]',
#  'jmp71d7f',
#  'jge0d30',
#  'negdword[rbp-30]',
#  'leardx,[7+1179f9]',
#  'movrax,qword[rax+f0]',
#  'learax,[7+f9fc9]',
#  'jmpqword[6+336152]',
#  'jeed9bb',
#  'je5b52f',
#  'movqword[rbp-880],rax',
#  'jne953b4',
#  'jmpe1ee1',
#  'learsi,[7+116044]',
#  'movqword[rbp-f0],rcx',
#  'jne582ac',
#  'learsi,[7+10f7e3]',
#  'push2f5',
#  'jedf118',
#  'jnee0554',
#  'jnee077e',
#  'leardi,[7+10b724]',
#  'callcbb30',
#  'movrax,-2',
#  'movesi,506',
#  'learax,[7+33b1e1]',
#  'jmp4fcae',
#  'je93bf5',
#  'andesi,3fff',
#  'call486a0',
#  'movdword[rax+14],4',
#  'movrax,qword[rbp-2040]',
#  'jmp7a2e1',
#  'jmp53860',
#  'movesi,347',
#  'js8c48b',
#  'leardx,[7+250447]',
#  'je994c8',
#  'cmpeax,19d',
#  'addqword[rbp-30],1',
#  'learax,[7+fcdd1]',
#  'leardx,[7+103df2]',
#  'learax,[rbp-110]',
#  'jne6ca64',
#  'jmp99b73',
#  'testcl,40',
#  'jee7727',
#  'call950f4',
#  'movsxdrdx,dword[rax+rdi*4]',
#  'calla5f37',
#  'shlesi,a',
#  'movr13d,dword[rbx+94]',
#  'leardx,[7+f7a2e]',
#  'jmpe1964',
#  'movr13d,eax',
#  'je75ff4',
#  'jmpcece3',
#  'movword[rbp-10],dx',
#  'addqword[rbp-18],rax',
#  'je6c243',
#  'push47',
#  'movdword[rbp-205c],eax',
#  'jne51611',
#  'je502d8',
#  'movqword[rax+8],rcx',
#  'je6240c',
#  'jmp6c7b3',
#  'jmp823f1',
#  'jne690a3',
#  'moveax,10f',
#  'push9e',
#  'jbbcf30',
#  'jnscecf1',
#  'learcx,[7+10fe71]',
#  'je5e1b8',
#  'jne84ccb',
#  'learsi,[7+f7a6a]',
#  'je9f3f8',
#  'jbebd827',
#  'leardx,[7+3489a9]',
#  'moveax,dword[rbp-2074]',
#  'learax,[7+24cc7d]',
#  'jed3439',
#  'learsi,[7+111940]',
#  'je7ef09',
#  'jmp9348c',
#  'jnec84ca',
#  'movqword[rsp+10],rbx',
#  'moveax,dword[6+2ad11b]',
#  'movqword[11+34045d],0',
#  'learsi,[7+10ed92]',
#  'jnea6a38',
#  'push35b',
#  'movedi,1a',
#  'jne9dfe1',
#  'jmpefaa0',
#  'movesi,155',
#  'movr9,rbx',
#  'movzxeax,byte[rax+44]',
#  'testr14b,7',
#  'movqword[rax+248],rcx',
#  'call45df0',
#  'je7f5ef',
#  'jne8f05a',
#  'movr12d,dword[rbp+50]',
#  'movdword[rbp-54],0',
#  'lear9,[rbp-20a8]',
#  'jecf119',
#  'jneb3b56',
#  'jmpa87da',
#  'learcx,[rbp-830]',
#  'jleab634',
#  'subrsp,110',
#  'call48850',
#  'movqword[rsp+10],r10',
#  'cmpeax,4b',
#  'jnef644d',
#  'jmp84ef2',
#  'movddupxmm4,xmm0',
#  'jnee30ed',
#  'jne6b3e6',
#  'jmpd18fa',
#  'je6a5f4',
#  'movqword[11+33f305],0',
#  'shlrax,4',
#  'leaeax,[rdx-1]',
#  'movesi,630',
#  'movedi,dword[rdi]',
#  'jmpda31a',
#  'movecx,6',
#  'learsi,[7+109764]',
#  'jmpd1cd6',
#  'jne76e0c',
#  'cmpqword[rbp-1c0],0',
#  'jeccb56',
#  'jmp9d637',
#  'jmpa8479',
#  'leardi,[7+10505d]',
#  'je5cb5c',
#  'learax,[7+fa841]',
#  'negrax',
#  'jnec8102',
#  'movqword[rax+58],rdx',
#  'jec76cc',
#  'movrcx,qword[r12+18]',
#  'jmpecb9e',
#  'lear13,[rax+1]',
#  'learsi,[7+33f191]',
#  'jne8383f',
#  'jea242a',
#  'leardx,[rbp-140]',
#  'movesi,dword[rsp+c]',
#  'calla56ed',
#  'jedea53',
#  'jg54752',
#  'leardx,[7+113999]',
#  'leaesi,[rbp+r14]',
#  'movssxmm0,[rdi+4]',
#  'movr9d,dword[rbp-4c]',
#  'jmpa2682',
#  'jne91424',
#  'je6fa32',
#  'cmprax,qword[rbp-8]',
#  'cmpqword[rbp-10],13ff',
#  'leardi,[7+105e2a]',
#  'push326',
#  'jmp776b3',
#  'learcx,[7+1033c0]',
#  'addr11,rsi',
#  'leardx,[rbx+44]',
#  'ucomissxmm0,xmm2',
#  'cmpdword[rbp-34],257',
#  'movzxr13d,byte[rax-1]',
#  'learsi,[7+108628]',
#  'cmpebx,ecx',
#  'jed643c',
#  'ja8e29a',
#  'je772c4',
#  'addrsp,40',
#  'movrcx,qword[rax+198]',
#  'leardx,[7+fe52b]',
#  'lear13,[7+10a8b9]',
#  'leardx,[7+103bfc]',
#  'moveax,dword[rax+38]',
#  'learax,[7+1155c1]',
#  'jmpa3bcf',
#  'cmpr15d,r14d',
#  'jecd6f5',
#  'call46300',
#  'jeb6b76',
#  'jea0f85',
#  'movrax,qword[7+2f4a41]',
#  'jeccd7d',
#  'learsi,[7+115389]',
#  'jnebfef0',
#  'jne9e4ba',
#  'je75b8c',
#  'learsi,[7+1141f3]',
#  'learax,[7+fa5c9]',
#  'je82a25',
#  'movr10d,8',
#  'learax,[7+2d7dc3]',
#  'movrcx,qword[rbp-20]',
#  'jmpc1c20',
#  'jnebcb08',
#  'jmp9804d',
#  'je85a02',
#  'jnec8f8a',
#  'push227',
#  'je5f961',
#  'jmp8e8fd',
#  'moveax,dword[6+3a8b62]',
#  'movr12d,dword[r8+1c]',
#  'movr15d,0',
#  'moveax,dword[rbp-2c44]',
#  'je8d15a',
#  'cmovneesi,eax',
#  'jne5e951',
#  'learax,[7+fd609]',
#  'movssxmm1,[rdx+rax*8]',
#  'leardi,[7+fcee3]',
#  'jne5bb22',
#  'call462c0',
#  'subqword[rbp-60],rax',
#  'xoreax,1',
#  'moveax,11187',
#  'jedccd2',
#  'jecf5df',
#  'jneb2b68',
#  'movebx,3',
#  'jed1084',
#  'cmpal,59',
#  'jled0264',
#  'adddword[rbp-8],5',
#  'jabccdf',
#  'jef181f',
#  'addrsp,30',
#  'leardi,[7+f2094]',
#  'call4b2d0',
#  'learax,[7+fd900]',
#  'learsi,[7+1034cb]',
#  'cmpedi,edx',
#  'movrax,qword[7-ca37a]',
#  'learsi,[7+115d97]',
#  'calle7ca2',
#  'movdword[rsp-40],eax',
#  'learax,[7+7409c]',
#  'jmp973af',
#  'learax,[7+33f211]',
#  'callc3ce0',
#  'jed1bf0',
#  'movzxr10d,byte[r14+a]',
#  'leardx,[7+d9862]',
#  'learax,[7+33fc39]',
#  'je55835',
#  'jebcc8a',
#  'jmp5d38c',
#  'jne5b924',
#  'movdword[rax+3c],edx',
#  'jne83643',
#  'learax,[7+ffd27]',
#  'callb372b',
#  'movqword[rbp-80],r9',
#  'learax,[7+bb859]',
#  'jneacfa1',
#  'learax,[7+f27b6]',
#  'addrdx,9',
#  'movqword[rbp-88],rdx',
#  'call74256',
#  'ordword[rbp-3c],100',
#  'imulebp,dword[rbx+28]',
#  'subedi,9',
#  'leardx,[7+d9a9f]',
#  'jmp8e503',
#  'calldac42',
#  'movedi,dword[rbp-44]',
#  'learsi,[rsp+1]',
#  'leardi,[7+fe3d1]',
#  'jmpef838',
#  'jled05da',
#  'je8b17f',
#  'leardx,[7+1032a9]',
#  'call47b70',
#  'leardi,[rbp-e0]',
#  'call49691',
#  'jnea2886',
#  'cmpdword[rbp-94],1',
#  'jmp47b30',
#  'leardx,[7+fe514]',
#  'je67873',
#  'jed04c0',
#  'leaedx,[rbp+5]',
#  'ordword[rbp-14],eax',
#  'jee615e',
#  'leardx,[7+103a89]',
#  'shrecx,8',
#  'callqword[rbx+60]',
#  'leardx,[7+3aac99]',
#  'learsi,[7+9c8b7]',
#  'learax,[7+115669]',
#  'movqword[rsp+8],r8',
#  'je5ae0c',
#  'cmpdword[rbp-54],5',
#  'learsi,[7+ed730]',
#  'orr9,r8',
#  'jneaaa1e',
#  'jgb2820',
#  'movssxmm0,[8+10a650]',
#  'movebp,ffffffff',
#  'jned8f6e',
#  'cmpqword[rbp-138],0',
#  'learax,[7+bd389]',
#  'jmp89c00',
#  'jmp881cc',
#  'jmpqword[6+336792]',
#  'movesi,dword[rbp-44]',
#  'shlebx,cl',
#  'call48590',
#  'jg5e5b4',
#  'jns91085',
#  'jmpd992b',
#  'movrax,qword[rax+138]',
#  'push308',
#  'movdword[10+35c232],0',
#  'cmpr11d,eax',
#  'movqword[rdx+40],rax',
#  'movrbx,qword[rax+58]',
#  'movedx,62',
#  'leardi,[7+114a13]',
#  'jmp93069',
#  'xordil,byte[rdx+rax]',
#  'jne9dc1f',
#  'andecx,3',
#  'movr12,rcx',
#  'jmp4e227',
#  'push20b',
#  'leardi,[7+102531]',
#  'jbec4280',
#  'jnea90a2',
#  'je555e2',
#  'je958d8',
#  'jmp59ac0',
#  'moveax,dword[rax+58]',
#  'moveax,dword[6+2b2c38]',
#  'subrbx,1',
#  'movzxeax,byte[rsi]',
#  'movecx,dword[rbp-18]',
#  'learsi,[7+f88df]',
#  'lear9,[rax+68]',
#  'jnedcd0d',
#  'jmp885b4',
#  'jnec1ed0',
#  'push105',
#  'movqword[rbp-48],8',
#  'movdword[rbp-70],3',
#  'je58d89',
#  'addr13,8',
#  'jne4ff77',
#  'movdword[rbp-140],203d563b',
#  'leardi,[7+104f35]',
#  'call9b3ce',
#  'leardi,[7+1059df]',
#  'movr14d,dword[rbp-54]',
#  'je74c21',
#  'jmpqword[6+336a42]',
#  'movsd[rbp-58],xmm0',
#  'jgda6ea',
#  'jmp49ea4',
#  'push275',
#  'leardi,[7+7d170]',
#  'jea1322',
#  'jef04fd',
#  'jnee00a9',
#  'learax,[7+ffa29]',
#  'jleb2dfa',
#  'movdword[rdx+1cc],eax',
#  'movqword[rbp-120],rsi',
#  'jmp8fdc7',
#  'jmp63b78',
#  'jne5c280',
#  'movrdi,r8',
#  'leardx,[7+1115ad]',
#  'jmp59b8f',
#  'jneec174',
#  'jmpqword[6+33724a]',
#  'leardi,[7+116c59]',
#  'movrdx,qword[rax+2b8]',
#  'jmp60988',
#  'jmpa3584',
#  'jle8fef1',
#  'jmpeaca2',
#  'movesi,6c8',
#  'learax,[7+f88f9]',
#  'jec8a9d',
#  'je58c7a',
#  'learsi,[7+1087b7]',
#  'movqword[rbp-80],rsp',
#  'testrsi,rsi',
#  'jmpqword[6+336332]',
#  'movdword[rbp-24],edi',
#  'call48b40',
#  'jleedc65',
#  'je51393',
#  'jmpe7eff',
#  'movdword[rbp-8],11187',
#  'call7b28d',
#  'learsi,[7+105d13]',
#  'je95925',
#  'jmpd4e0c',
#  'leardi,[7+10505b]',
#  'jmpefcce',
#  'addeax,edi',
#  'learax,[7+ff01e]',
#  'learax,[7+18957]',
#  'leardx,[7+51e04]',
#  'movedx,dword[rdx+rcx*4]',
#  'movesi,dword[rbp-94]',
#  'je80fb1',
#  'je7277b',
#  'je6c804',
#  'js8d05b',
#  'jnecc1f8',
#  'call866c5',
#  'jbe4cb7e',
#  'push267',
#  'jbebedf5',
#  'leardi,[7+10be61]',
#  'je4f3f9',
#  'learax,[7+101219]',
#  'movrax,qword[rbp-20e0]',
#  'jea2453',
#  'learcx,[7+71c30]',
#  'leardi,[7+105dd2]',
#  'jne9a229',
#  'movqword[rbp-910],80',
#  'cmpqword[rbp-20f0],0',
#  ...}
